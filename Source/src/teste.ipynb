# %%
import numpy as np
lista = sorted([1,2,3,6,5,7,7], reverse=True)
lista = sorted(np.unique(lista), reverse=True)

lista#index(5)
# Out:
# [np.int64(7), np.int64(6), np.int64(5), np.int64(3), np.int64(2), np.int64(1)]
